# %% [markdown]
# # Journal de Bord - Campus Market

# %% [markdown]
# ## Séance 1 - Vendredi 6 Mars 2026
#
# - Prise de connaissance du sujet.
# - Analyse de la situation et idée de solution afin de créer ce projet.
# - Mise en place du **Cahier des Charges** v1 et du **Journal de Bord**.

# %% [markdown]
# ## Séance 2 - Vendredi 20 Mars 2026
#
# - Initialisation de l'architecture de base du projet et de l'**architecture MVC**.
# - Création et Initialisation du **Git** via le terminal (lié avec le projet VS Code).
# - Création du dossier **database** et du fichier **setup.sql**
# - Initialisation du dossier **setup.sql**
# - Création du fichier **Database.php**
# - Initialisation du fichier **Database.php**

# %% [markdown]
# ## Séance 3 - Vendredi 03 Avril 2026
#
# - Création de la base de données via **PhpMyAdmin** et **Xampp**.
# - **Initialisation** de cette base de données
# - Création du fichier **index.php** qui contiendra la page d'accueil du site.
# - Test de la base de données. (Fonctionnelle).
# - Création du dossier **includes** contenant les fichiers **header.php** et **footer.php**.
# - Initialisation des fichiers **header.php** et **footer.php**.
# - Initialisation du fichier **index.php** avec le **header.php** ainsi que le **footer.php**.
# - Création du fichier **style.css**.
# - Finalisation de l'inscription dans le fichier **register.php** :
#     - **Connexion à la base de données** : Liaison du formulaire PHP à la base de données MySQL via PDO.
#     - **Sécurité des données** : Mise en place du hashage des mots de passe avec **password_hash()**. Vérification dans PhpMyAdmin que les mots de passe était hashé correctement.
#     - **Redirection intelligente** : Configuration du script qui permet de renvoyer l'utilisateur directement sur la page d'accueil (**index.php**).
# - Création du système de session :
#     - Identité persistante : Utilisation de **session_start()** pour que le site se souvienne de l'utilisateur d'une page à l'autre lorsque le site sera complet et manipulable.
#     - **Expérience "Sans Friction"** : Décision de faire en sorte que l'utilisateur soit connecté directement après l'inscription sur le site plutôt que de devoir se connecter de nouveau sur la page login comme créer au début.
# - Développement de système de **connexion** :
#     - **Formulaire de Login** : Création de l'interface **login.php**.
#     - **Moteur d'authentification** : Création de **process_login.php** qui utilise **password_verify()** pour comparé le mot de passe tapé à celui stocké dans la base de données.
#     - **Gestion des erreurs** : Mise en place de paramètres dans l'URL pour préparer l'affichage des messages d'erreurs.
# - Dynamisation de la **Page d'Accueil** :
#     - **Message de Bienvenue dynamique** : Affichage d'un bandeau "Welcome to the Community !" pour les nouveaux inscrits.
#     - **Nettoyage du Code** : Correction des erreurs de syntaxe PHP et sécurisation de l'affichage.
# - **Victoire Technique Majeur** :
#     - **Première insertion** : Création d'un utilisateur dans la base de données.
#     - **Communication Full-Stack** : Validation de la chaîne Front-End <-> Backend <-> Base de Données.

# %% [markdown]
# ## Séance 3.1 - Dimanche 5 Avril 2026
#
# - Sécurisation de la Base de Données :
#     - **Mise en place de la contrainte d'unicité** : Modification de la structure de la table **users** dans MySQL pour définir la colonne **email**comme **UNIQUE**. Cela garantit mathématiquement qu'aucun doublon ne peut exister dans la base de données.
#     - **Gestion des Exceptions PDO** : Amélioration du script **process_register.php** avec un bloc **try/catch** spécifique. Le code détecte désormais l'erreur SQL pour éviter un plantage du site.
#     - **Amélioration de l'expérience utilisateur** : Mise en place d'un système de redirection avec information d'erreurs.
# <br>
# <br>
#
# - Dynamisation de l'Interface & Structure de Vente :
#     - **Header "Intelligent** : Mise en place de l'affichage conditionnel : le menu change selon l'état de connexion **(is isser($_SESSION))**.
#     - **Affichage personnalisé** : Ajout du message de bienvenue "Hi, Yanis!" (lié à la base de données).
#     - **Système de Déconnexion** : Création du script **logout.php** permettant de détruire proprement la session et rediriger l'utilisateur vers l'accueil en toute sécurité.
#     - **Base de Données - Table listings** : Architecture de la table annonces finalisée. La base de données est donc désormais prête à recevoir toutes les données du futur formulaire de vente.
#     - **Navigation & Flux** : Vérification des liens entre les pages : index -> login -> register -> index (en étant connecté). Le bouton "List Item" est désormais prêt à pointer vers le formulaire de création d'annonces.

# %% [markdown]
# # Séance 3.2 - Lundi 6 Avril 2026
#
# - Formulaire de Vente (**list_item.php**)
#     - Création de l'interface de mise en vente en respectant le design actuel.
#     - **Mise en place de la sécurité** : seuls les utilisateurs connectés peuvent accéder au formulaire.
#     - Synchronisation des catégories avec ta base de données (Textbooks, Electronics, etc...).
# <br>
# <br>
#
# - Moteur d'Insertion (**process_list_item.php**)
#     - Développement du script de traitement des données.
#     - **Résolution de bug** : Adaptation du code pour fonctionner avec l'architecture Singleton.
#     - Gestion des erreurs PDO pour sécuriser l'envoi des données.
# <br>
# <br>
#
# - Première Donnée Réelle :
#     - **Test réussi à 11:23 A.M.** : Insertion confirmée dans la table **listings**.
#     - Vérification des liaison : le **user_id** et le **category_id** remontent parfaitement.
# <br>
# <br>
#
# - Affichage des offres (**browse.php**) :
#     - Création du fichier browse.php.
#     - Implémentation du fichier browse.php qui vient tirer les offres de la table **listings** afin de les afficher sur la page.
# <br>
# <br>
#
# - Synchronisation du Statut (Statuts) :
#     - Mise en place du filtre **"active"** : les annonces ne s'affichent que si leur statut est marqué comme actif dans la base de données.
#     - Mise en cohérence des options d'état (new, used, refurbished) entre le formulaire et la table SQL pour éviter les erreurs d'affichage.

# %% [markdown]
# # Séance 3.3 - Lundi 13 Avril 2026
#
# - Gestion des Images (Uploads) :
#     - Création d'un dossier physique **/uploads** pour stocker les photos des produits sur les serveurs.
#     - Modification du formulaire de vente pour autoriser l'envoi de fichiers lourds.
#     - Mis à jour du fichier **process_list_item.php** pour générer des noms de fichiers uniques (évite que deux photos avec le même nom ne s'écrasent).
#
# - Liaison Base de Données (SQL) :
#     - Ajout de la colonne **image_url** dans la table **listings**.
#     - Modification de la requête d'insertion pour enregistrer le nom du fichier image en même temps que le texte de l'annonce.
#
# - Affichage dynamique (browse.php) :
#     - Mis à jour de la galerie pour afficher la vraie photo de l'objet.
#     - Ajout d'une condition d'affichage : si l'objet n'a pas de photo, le site affiche un message par défaut ("No Image Yet").
#     - Utilisation du style CSS **"object-fit : cover""** pour que toutes les images soient parfaitement alignéees et pro, peu importe leur taille d'origine.
#
# - Test de Validation Finale :
#     - Succès total : Une annonce de test a été publiée avec une image réelle.
#     - Le fichier est bien présent dans le dossier du serveur et l'image s'affiche correctement dans la galerie des offres.
#
# - Page de Détails du Produit **(product_details.php)** :
#     - Création d'une page dynamique qui affiche les informations complètes d'un article en fonction de son ID.
#     - Maîtrise des Jointures SQL (JOIN) : Implémentation d'une requête complexe pour lier la table **listings** et la table **users**. Cela permet d'afficher le nom complet du vendeur au lieu de son simple numéro d'identifiant.
#     - Gestion d'affichage dynamique : Utilisation de n12br() pour respecter les sauts de ligne de la description et le formatage de la date pour une meilleure lisibilité.
#
# - Refont de la Page d'Accueil **(index.php)** :
#     - Mise en place d'un affichage dynamique des 20 dernières annonces via SQL (ORDER BY DESC)
#     - Optimisation de l'UX (Expérience Utilisateur) en inversant les sections pour mettre en avant les produit dès l'arrivée sur le site.
#     - Création d'un "Hero Section" avec appel à l'action pour diriger le trafic vers le catalogue ou le formulaire de vente.
#
# - Système de Recherche Global (Header & browse.php) :
#     - Décentralisation de la Recherche : Déplacement de la barre de recherche dans le header.php pour la rendre accessible depuis n'importe quelle page du site.
#     - Logique de Filtrage par Mot-Clé : Utilisation de l'opérateur SQL LIKE avec des jokers % pour permettre une recherche flexible sur les titres et les descriptions.
#     - Gestion des Etats : Mise en place d'un indicateur de recherche active sur la page catalogue et d'une gestion des cas "aucun résultat" pour améliorer la navigation.

# %% [markdown]
# # Séance 3.4 - Mardi 14 Avril 2026
#
# - Création du Dashboard Utilisateur **(my_listings.php)** :
#     - Objectif : Permettre aux utilisateurs de gérer leur propre inventaire sur la plateforme.
#     - Réalisation : Mise en place d'une interface de gestion affichant exclusivement les annonces de l'utilisateur connecté via une requête SQL filtrée par **user_id**.
#     - Sécurité : Intégration d'une vérification de ession pour restreindre l'accès aux membres authentifiés.
#
# - Implémentation du Système de Suppression (delete_listings.php).
#     - Logique de contrôle : Développement d'un script de suppression sécurisé qui vérifie la double condition : l'ID de l'annonce et l'ID de l'utilisateur en propriétaire. Cela empêche qu'un utilisateur puisse supprimer l'annonce d'un autre en manipulant l'URL.
#     - Intéractivité : Ajout d'une boîte de dialogue de confirmation en JavaScript **(confirm)** pour éviter les suppressions accidentelles.
#     - Gestion des retours : Mise en place d'un système de messages de succès (via les paramètres GET) pour confirmer l'action à l'utilisateur.
#
# - Optimisation de la Navigation (Header) :
#     - Amélioration de l'UX : Mise à jour du header.php pour inclure un accès direct au dashboard ("My Ads").
#     - Design : Séparation visuelle entre la navigation publique et les outils personnels pour une interface plus intuituve et professionnelle.
#
# - Implémentation du Système de Tri par Catégorie :
#     - Objectif : Strucuturer l'offre du MarketPlace pour faciliter la navigation et permettre aux étudiant de trouver rapidement des objets spécifiques (Livres, Dévo, Fournitures).
#     - Mise en place d'une barre de filtrage dynamique sur **browse.php** avec les catégories réelles de la base de données (Textbooks, Dorm Decor, School Supplies, etc...).
#     - Développement d'une logique de filtrage par URL (méthode GET) permettant de passer les IDs de catégories.
#     - Optimisation de la raquête SQL dynamique : Ajout d'une claise **WHERE category_id = :id** qui s'active uniquement si une catégorie est sélectionnée, sans briser la recherche par mot déjà existante.
#     - Mise en place d'un retour visuel (bouton bleu vs gris) afin d'indiquer la catégorie active.
#     - Création d'un état **No Items Found** stylisé avec un bouton de réinitialisation, pour améliorer l'expérience utilisateur lorsqu'un filtre ne donne aucun résultat.

# %% [markdown]
# # Séance 3.5 - Mercredi 15 Avril 2026
#
# - **Refonte du Footer** : Passage d'un pied de page basique à une structure multi-colonnes professionnelle.
# - **Intégration de l'écosystème Duke Blue Devils** : Ajout des liens externes vers les ressources du campus et les équipes sportives pour renforcer l'immersion.
# - **Mention de Disclaimer** : Ajout d'une note légale précisant le cadre pédagogique du projet (sécurité utilisateur).
#
# - Finalisation de l'interface Marketplace Blue Devil Exchange et mise en place du design responsive (adaptation mobile).
#     - Page d'Accueil : nettoyage complet des styles inline. Mise en place d'une section 'hero' dynamique et d'une bannière de bienvenue responsive qui s'adapte à la taille de l'écran sans marges fixes.
#     - Page de Recherche : Mise en place d'une grille de produits qui devient flexibles puisqu'elle contient plusieurs colonne sur desktop pour n'en obttenir qu'une seule sur mobile.
#
# - Harmonisation CSS : Centralisation des styles dans un ficher style.css plutôt que dans le HTML sur la plupart des fichiers.
#
# ### **Problèmes rencontrés & Points de Blocage** :
#
# - Header & Navigation : Difficultés persistantes sur le menu de navigation responsive : Le mélange entre les anciens styles **flexboxs** et les nouvelles règles de superposition crée des conflits visuels.
# - Footer : La structure multi-colonne ne s'empile pas encore correctement sur les écrans les plus étroits.

# %% [markdown]
# # Séance 4 - Jeudi 16 Avril 2026 (Autonomie)
#
# - Récupération des paramètres via URL (Méthode GET) : Utilisation de la superglobale $_GET['sort'] pour capturer l'intention de l'utilisateur.
#
# - Logique de sélection : Mise en place d'un bloc switch en PHP pour traduire le choix de l'utilisateur en langage SQL sécurisé.
#
# - Concaténation SQL dynamique : La clause de tri est ajoutée dynamiquement à la fin des requête SQL principale avant son exécution. Cela permet de combiner le tri avec les filtres de recherche et de catégorie déjà existants.
#
# - Récupération sécurisée (edit_listings.php) : Création d'un formulaire de modification qui récupère les données actuelles via l'identifiant de l'objet.
#
# - Vérification de l'intégrité et des droits : Implémentation d'une double vérification dans la clause WHERE. La requête SQL ne fécupère l'objet que si l'ID correspond ET que le user_id en session est bien celui du propriétaire Cela empêche un utilisateur malveillant de modifier l'annonce d'un autre via l'URL
#
# - Gestion des états de formulaire : Utilisation de l'attribut selected en PHP pour pré-remplur dynamiquement le menu déroulant des catégories avec la valeur actuelle stockéee en base.
#
# - Traitement des données (process_edit.php) : Utilisation de la commande SQL UPDATE via des requêtes préparées PDO pour enregistrer les modifications tout en protégeant le serveur contre les inejctions SQL.
#
# ## Déploiement
#
# - Choix de l'infrastructure :
#     - Action : Analyse des solutions d'hébergement pour la mise en ligne du projet.
#     - Décision : Utilisation d'un hébergement mutualisé LAMP (Linux, Apache, MySQL, Php) via InfinityFree au lieu d'un VPS, afin de garantir une configuration serveur stable et pré-optimisée pour le rendu final du projet.
#
# - Migration de la base de données :
#     - Etape 1 : Exportation de la base de données locale (format .sql) via phpMyAdmin.
#     - Etape 2 : Création d'une instance MySQL distante sur le serveur de production.
#     - Résolution Technique : Importation du schéma relationnel et ajustement des privilèges utilisateur.
#
# - Confiugration et connectivité :
#     - Problème rencontré : Erreur **ConnectionError : SQLSTATE[HY000] [2002] lors du premier lancement.
#     - Diagnostic : Tentative de connexion sur **localhost** au lieu du serveur distant car je n'avais pas encore pensé à changer les liens d'accès dans le fichier **Database.php**
#     - Correction : Mise à jour du DSN (Data Source Name) dans la calsse Database.php avec le hostname fourni par l'hébergeur.
#     <br>
#     <br>
#     - Problème rencontré : **Access denied for user 'root'**.
#     - Correction : Remplacement des identifiants de développement par les accès sécurisés de production.
#
# - Déploiement des fichiers (FTP) :
#     - Action : Tranfert de l'intégralité du code source via le client FileZilla (version portable pour contourner les restrictions de sécurité Windows Smart App Control).
#     - Organisation : Respect de l'arborescence **htdocs/**.
#     - Optimisation : Mise en place d'un fichier **.htaccess** à la racine pour rediriger le trafic vers le dossier **/public**, permeettant ainsi qde conserver une architecture sécurisée sans exposer les fichiers de configuration.
#
# - Recette finale (Tests) :
#     - Validation : Test de l'URL publique **http://blue-devil-exchange.infinityfree.me**
#     - Vérification : Confirmation du bon fonctionnement du CRUD (affichage des articles depuis la base distante) et du système d'upload d'images (vérification des permissions CHMOD sur le dossier **/uploads**).
